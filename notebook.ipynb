# %% [markdown]
# <a href="https://colab.research.google.com/github/tselane2110/Fall-Detection-Using-OpenPose-and-MobileNetV2/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cloning OpenPose from HuggingFace

# %%
# removing the by-default folder we get on colab

# !rm -r /content/sample_data

# %%
# cloning my repo
# !git clone https://github.com/tselane2110/Fall-Detection-Using-OpenPose-and-MobileNetV2
# Out:
# Cloning into 'Fall-Detection-Using-OpenPose-and-MobileNetV2'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 27 (delta 5), reused 16 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 192.15 KiB | 1.55 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd Fall-Detection-Using-OpenPose-and-MobileNetV2
# Out:
# /content/Fall-Detection-Using-OpenPose-and-MobileNetV2

# %%
# Install git-lfs
# !apt-get install -y git-lfs
# !git lfs install
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Updated git hooks.
# Git LFS initialized.

# %%
# !git clone https://huggingface.co/camenduru/openpose
# Out:
# Cloning into 'openpose'...
# remote: Enumerating objects: 3569, done.
# remote: Total 3569 (delta 0), reused 0 (delta 0), pack-reused 3569 (from 1)
# Receiving objects: 100% (3569/3569), 19.88 MiB | 16.76 MiB/s, done.
# Resolving deltas: 100% (1100/1100), done.
# Filtering content: 100% (74/74), 903.21 MiB | 64.00 MiB/s, done.

# %%
# Checking the OpenPose directory structure
# !ls -la openpose/models/pose/
# Out:
# total 20
# drwxr-xr-x 5 root root 4096 Dec  7 08:52 .
# drwxr-xr-x 6 root root 4096 Dec  7 08:52 ..
# drwxr-xr-x 2 root root 4096 Dec  7 08:52 body_25
# drwxr-xr-x 2 root root 4096 Dec  7 08:52 coco
# drwxr-xr-x 2 root root 4096 Dec  7 08:52 mpi

# %%
# installing dependencies
# !pip install -r requirements.txt

# %%
# meant to test if openpose is working on a test_image
# !python quick_test.py
